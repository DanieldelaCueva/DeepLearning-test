# %% [markdown]
# <a href="https://colab.research.google.com/github/DanieldelaCueva/DeepLearning-test/blob/main/Pytorch/Pytorch_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
